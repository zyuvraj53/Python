# %%
api_key = "AIzaSyBcFYRif86FKOm99sfuCHu9y0nvhTrDy_0"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
res = youtube.commentThreads().list(part="snippet",
                                    videoId="qy4OmeTuNQ8",
                                    maxResults = 100).execute()

# %%
res
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'B-m6MVFUrCF6df__wSTkEVsnRgU',
#  'nextPageToken': 'QURTSl9pMW5qZXo5b0l5R1R4eGh3REdxcy1IT2psc1c2RVVVSEN2bDJKRkVTSHlhdUwwR0g3MHhndUJzR0lkQURhMlRwNjN6cllZNktRSl9tYXFha3dYaTc1ZmVFTjlJ',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'a-zd_pXnXWXeMVpq0xgZoHbBNMU',
#    'id': 'Ugx6yE54hsS1F5dHp9R4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Wyu68k76GzArRuW8Ic0a0xH8eJI',
#      'id': 'Ugx6yE54hsS1F5dHp9R4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I realize a lot of you are missing some important context, I made this video talking about why a lot of these dishes are, the way they are: <a href="https://www.youtube.com/watch?v=Dbi3EG4r8kM&amp;t=">https://www.youtube.com/watch?v=Dbi3EG4r8kM&amp;t=</a>',
#       'textOriginal': 'I realize a lot of you are missing some important context, I made this video talking about why a lot of these dishes are, the way they are: https://www.youtube.com/watch?v=Dbi3EG4r8kM&t=',
#       'authorDisplayName': 'Beryl Shereshewsky',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSEgt5lNpJPkQbllf731PuAB0Oa1q_FJViNFa6GFw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbPHHOiOY_tA9BSytK0jDYw',
#       'authorChannelId': {'value': 'UCbPHHOiOY_tA9BSytK0jDYw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 321,
#       'publishedAt': '2021-06-03T13:39:57Z',
#       'updatedAt': '2021-06-03T14:25:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 32,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EaNt1jKpEuTatX0ioG1jk8gD79s',
#    'id': 'UgzCv4OzQD2L0ispXp14AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'z3Fs4pqNVLHq_idX_EdcIuB9QkY',
#      'id': 'UgzCv4OzQD2L0ispXp14AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'The lime jello salad is Watergate salad, originated at the Watergate Hotel (yes, same one as Nixon&#39;s scandal).',
#       'textOriginal': "The lime jello salad is Watergate salad, originated at the Watergate Hotel (yes, same one as Nixon's scandal).",
#       'authorDisplayName': 'Shari Powers',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQIj31dPHlIz1ZMx_i_9mEbTLJLo6frhpUflMuT=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCDj_8PBAIS0oQg8TqJKdgtQ',
#       'authorChannelId': {'value': 'UCDj_8PBAIS0oQg8TqJKdgtQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-02T16:51:22Z',
#       'updatedAt': '2021-09-02T16:51:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JT93dRTDvIt41fTktD6I_B1Vmt4',
#    'id': 'Ugz0583uLhKzjRBzOI14AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zJKgAVn5P91TuwD19LD4T21PREc',
#      'id': 'Ugz0583uLhKzjRBzOI14AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Your first dish of the video just so happens to be what I&#39;m making tonight for dinner.<br>HOWEVER! I grew up with my mom adding corn to it, and I can&#39;t have it without the corn. without the corn, it reminds me of that hash stuff in a can that I&#39;ve always hated.<br>I&#39;ve also never had this with ketchup before..but my boyfriend.. he grew up having it without corn, and with ketchup!',
#       'textOriginal': "Your first dish of the video just so happens to be what I'm making tonight for dinner.\nHOWEVER! I grew up with my mom adding corn to it, and I can't have it without the corn. without the corn, it reminds me of that hash stuff in a can that I've always hated.\nI've also never had this with ketchup before..but my boyfriend.. he grew up having it without corn, and with ketchup!",
#       'authorDisplayName': 'Jamie Ann',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLStqqhV2vQL72JxHGhN-1OM1aSaWmVR54CylUsd=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1yK88f208gekT2QH6_Dnww',
#       'authorChannelId': {'value': 'UC1yK88f208gekT2QH6_Dnww'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-02T03:50:28Z',
#       'updatedAt': '2021-09-02T03:52:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0D0kZGBYp1vaTY1yO1uIefiuFdo',
#    'id': 'UgyjC8iYHNeYDcdKqTZ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2SLHxNwF-hUwMQsW_4p3GA72ZAg',
#      'id': 'UgyjC8iYHNeYDcdKqTZ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'The jellos salads come in so many different recipes and names. My mom made what she called ambrosia and it was a lime jellos salad ingredients slightly different than the one in this one.',
#       'textOriginal': 'The jellos salads come in so many different recipes and names. My mom made what she called ambrosia and it was a lime jellos salad ingredients slightly different than the one in this one.',
#       'authorDisplayName': 'Elizabeth Jaramillo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSFWUNJhhQAKH73qCXDjH8yVJQoZgqoceL-JtF2Tg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwZYyCS2cifXz7NBy7Tx-Kg',
#       'authorChannelId': {'value': 'UCwZYyCS2cifXz7NBy7Tx-Kg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-01T18:49:12Z',
#       'updatedAt': '2021-09-01T18:49:12Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1gRIGi1RMd8hTAhCq6HDajgzU60',
#    'id': 'UgyEf-UbkSGJIt4bCP54AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_wxf0fsl09Ub3usFFhSr9nzyWFw',
#      'id': 'UgyEf-UbkSGJIt4bCP54AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Never had an armadillo egg but jalapeño poppers where I live are made almost the same leave out the sausage and no garlic.  Wrap in bacon and then oven or grill.',
#       'textOriginal': 'Never had an armadillo egg but jalapeño poppers where I live are made almost the same leave out the sausage and no garlic.  Wrap in bacon and then oven or grill.',
#       'authorDisplayName': 'Elizabeth Jaramillo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSFWUNJhhQAKH73qCXDjH8yVJQoZgqoceL-JtF2Tg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwZYyCS2cifXz7NBy7Tx-Kg',
#       'authorChannelId': {'value': 'UCwZYyCS2cifXz7NBy7Tx-Kg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-01T18:38:55Z',
#       'updatedAt': '2021-09-01T18:39:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'kEpPwlLUCpGOO66N5d4kZk0ujNI',
#    'id': 'Ugw_DZGYR0Aci_3NMPh4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'qpVT0wSooZu8KLMdVTmR8KiaC9E',
#      'id': 'Ugw_DZGYR0Aci_3NMPh4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Strawberry pretzel dessert is something I do love but have only made once. My husband loves each of these ingredients, so I was so excited to make it for him - but he didn’t like it at all. 😂 What?  Really?  How can you not love it? 🤷🏻\u200d♀️',
#       'textOriginal': 'Strawberry pretzel dessert is something I do love but have only made once. My husband loves each of these ingredients, so I was so excited to make it for him - but he didn’t like it at all. 😂 What?  Really?  How can you not love it? 🤷🏻\u200d♀️',
#       'authorDisplayName': 'Tam2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQm7jP9IjAXiNlQtvOKRAKBXoMFRveigrByyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCb7d4MowXBqgvG9Ihbck6LQ',
#       'authorChannelId': {'value': 'UCb7d4MowXBqgvG9Ihbck6LQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-01T07:35:21Z',
#       'updatedAt': '2021-09-01T07:35:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MeFYK2TRADkxv91-hNhwER9HbrE',
#    'id': 'Ugw4T_RmaIpWAI3iTNZ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hmPrwe9uTyAtP085TpTg7A1J1Aw',
#      'id': 'Ugw4T_RmaIpWAI3iTNZ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I love lime jello salad - it brings back good memories',
#       'textOriginal': 'I love lime jello salad - it brings back good memories',
#       'authorDisplayName': 'Tam2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQm7jP9IjAXiNlQtvOKRAKBXoMFRveigrByyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCb7d4MowXBqgvG9Ihbck6LQ',
#       'authorChannelId': {'value': 'UCb7d4MowXBqgvG9Ihbck6LQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-01T07:30:51Z',
#       'updatedAt': '2021-09-01T07:30:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xj3apWOAQg-DFXGGPhxfihgbb9Q',
#    'id': 'UgzsBvxmVA5qSSIrpc14AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8aQ5AzPQx5ZCxJtUSJTmfl_c83w',
#      'id': 'UgzsBvxmVA5qSSIrpc14AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'You missed “cookie salad”!',
#       'textOriginal': 'You missed “cookie salad”!',
#       'authorDisplayName': 'Maren Williams',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR7bhybHfXyBpNUUZGKnsg2XVyV6EJJ-XJyBw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7bLwb6yanbPqrSGBpdtaow',
#       'authorChannelId': {'value': 'UC7bLwb6yanbPqrSGBpdtaow'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-09-01T05:48:04Z',
#       'updatedAt': '2021-09-01T05:48:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jZYmezelGI_D3DrRIs9BvJLiaqw',
#    'id': 'Ugzf9F06w9elwUbh7nd4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5Jeh3H9ucX7gk2NbDXG0hBbbf5Y',
#      'id': 'Ugzf9F06w9elwUbh7nd4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Did that man just call tater tots &quot;fancy&quot;?<br>🤣🤣',
#       'textOriginal': 'Did that man just call tater tots "fancy"?\n🤣🤣',
#       'authorDisplayName': 'Anonymous because I feel like it.',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQjXmXfCQoZR1OWUygT3a9Xq86bgWD3aJCyvtIaCQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWiDQ5mGikw-fNsI5j9Pyhw',
#       'authorChannelId': {'value': 'UCWiDQ5mGikw-fNsI5j9Pyhw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-31T22:23:14Z',
#       'updatedAt': '2021-08-31T22:23:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'WerUF0Ix5sUW83UStVjn-T0Y4cE',
#    'id': 'UgxnooLDGHMKNuNQnxt4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'z8AV7EZsJfkXUnXlEsAjdr5taVQ',
#      'id': 'UgxnooLDGHMKNuNQnxt4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'You should definitely try Funeral Potatoes. I live in Idaho, USA and had never heard of this until I moved here. But if you like savory potato dishes - oh my gosh - it&#39;s delish!',
#       'textOriginal': "You should definitely try Funeral Potatoes. I live in Idaho, USA and had never heard of this until I moved here. But if you like savory potato dishes - oh my gosh - it's delish!",
#       'authorDisplayName': 'Khalea Allen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQnxXpPvV3j1JIPnvLSDzvGvmVC64oJox5IW3F0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgLLVGPRnhC29psQgYKHJFw',
#       'authorChannelId': {'value': 'UCgLLVGPRnhC29psQgYKHJFw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-31T06:40:58Z',
#       'updatedAt': '2021-08-31T06:40:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '257E518M0gAHOUHPIk9Qf2vc4_I',
#    'id': 'Ugzt5gt3j37ykG5QPpd4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zSNkNkImUZilKv4AYV8dMgOdohc',
#      'id': 'Ugzt5gt3j37ykG5QPpd4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'That&#39;s definitely not the lime jello salad my grandma made. I&#39;ll have to find the recipe, but it was a favorite of ours! She made a strawberry jello version, too.',
#       'textOriginal': "That's definitely not the lime jello salad my grandma made. I'll have to find the recipe, but it was a favorite of ours! She made a strawberry jello version, too.",
#       'authorDisplayName': 'Alicia Lorincz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ8MhJOUHllpI5nFtD9hGJMQ0uDR2soaP6MqVg9fw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwj4T2ufUB_0Cl9wgBs97JQ',
#       'authorChannelId': {'value': 'UCwj4T2ufUB_0Cl9wgBs97JQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-31T03:21:58Z',
#       'updatedAt': '2021-08-31T03:21:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1iFbAfTNFfHSx7r7lTe0062FmtQ',
#    'id': 'Ugyx_p3EcBojGqaZQGN4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'jemWojYvoOH1l6q-sc10AgRlKUA',
#      'id': 'Ugyx_p3EcBojGqaZQGN4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Ooh ooh! Do elephant ears!!',
#       'textOriginal': 'Ooh ooh! Do elephant ears!!',
#       'authorDisplayName': 'Aparna Easwar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRV9yK-ABwdqFw4bJ-I9PHfcRKjq9-zNSrfmUe-RQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpHfiPpLNYDoFb30BhmiK0A',
#       'authorChannelId': {'value': 'UCpHfiPpLNYDoFb30BhmiK0A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-30T01:46:12Z',
#       'updatedAt': '2021-08-30T01:46:12Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 's-b947N71R4vNXDlV__qz9CoLpI',
#    'id': 'Ugw4DMCWzo0DEzVQxDZ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'P-Qgji6PR8BUpiF489j3atN4hQk',
#      'id': 'Ugw4DMCWzo0DEzVQxDZ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'My family does lime jello salad as well! Different but mostly the same',
#       'textOriginal': 'My family does lime jello salad as well! Different but mostly the same',
#       'authorDisplayName': 'Ashley McBride',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSxjN5eSVj6jsfQUX5rGx9X-EhoSA3ApbOhIoY1Rw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC77jiCFI_Ca42LZR2KJC61w',
#       'authorChannelId': {'value': 'UC77jiCFI_Ca42LZR2KJC61w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-29T23:47:05Z',
#       'updatedAt': '2021-08-29T23:47:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LH2ZNeHJBaEBCcPS5QStFAiFkN0',
#    'id': 'Ugznv1YYhVELCA-G3RJ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cYtnPC3z76cSk3CMi5HJgTEvUMs',
#      'id': 'Ugznv1YYhVELCA-G3RJ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Holy shit I love your shirt (the one with the cat collar at the beginning of the video)',
#       'textOriginal': 'Holy shit I love your shirt (the one with the cat collar at the beginning of the video)',
#       'authorDisplayName': 'Creeper Queendom',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTGS7vS8d7ftfcMvVXnoh4O9oPXIXyAq7t1JF8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgbDjihzLzvi-WCkKuz5XYA',
#       'authorChannelId': {'value': 'UCgbDjihzLzvi-WCkKuz5XYA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-29T20:05:07Z',
#       'updatedAt': '2021-08-29T20:13:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LmXsdxWI4HxMTcFj39xMl1tJv_0',
#    'id': 'Ugy4kM4Zi6DqMBimR054AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2oPr1_28B-bz5oaTa1H5WeaXTDI',
#      'id': 'Ugy4kM4Zi6DqMBimR054AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I can&#39;t believe amercians still buy and eat cool whip. It is basically just sugar and fat hold together with chemicals that cause chronical kidney disease - the reason why this porduct is banned in germany. Don&#39;t use it. Do yourself a favour and whip actual cream. Tastes better and is not so dangerous.',
#       'textOriginal': "I can't believe amercians still buy and eat cool whip. It is basically just sugar and fat hold together with chemicals that cause chronical kidney disease - the reason why this porduct is banned in germany. Don't use it. Do yourself a favour and whip actual cream. Tastes better and is not so dangerous.",
#       'authorDisplayName': 'Bazingarama',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLShykzP7ZfaY3XV3_awV-K9OOWzsBy_BRttxCyXWg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCT_ZCF2gcyRpJW4xiBT6ppw',
#       'authorChannelId': {'value': 'UCT_ZCF2gcyRpJW4xiBT6ppw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-29T14:59:43Z',
#       'updatedAt': '2021-08-29T14:59:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'O7JrI2PMRNi9grVBLgoaWFkVNik',
#    'id': 'UgwGd9Ml1abP-h2Bq_h4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'G1TdUEBPBoy0cKqZuCvxJZBzlfY',
#      'id': 'UgwGd9Ml1abP-h2Bq_h4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'my dad loves strawberry pretzel salad!!! he’s from Western PA',
#       'textOriginal': 'my dad loves strawberry pretzel salad!!! he’s from Western PA',
#       'authorDisplayName': 'Allyson Yenerall',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTxtkBvTKeiFE6eLfeDc5_6fBrSKL7QM1TVCSxeyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9mEd8mPx17bQ2kbhSMZ2Kg',
#       'authorChannelId': {'value': 'UC9mEd8mPx17bQ2kbhSMZ2Kg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-29T01:53:16Z',
#       'updatedAt': '2021-08-29T01:53:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_-YbUxx8qgL99oYV1EwYFuqR31Y',
#    'id': 'UgxBOYFLkxANzs0lPd54AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yKci2JTyfA5svToww2zfAlNjwjU',
#      'id': 'UgxBOYFLkxANzs0lPd54AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'As soon as you said “it’s salad but it’s not salad” I knew you were going to make something that my mother-in-law calls “salad”🤦🏼\u200d♀️ Yep…jello, marshmallows &amp; cool whip. Feel free to eat my portion 👌',
#       'textOriginal': 'As soon as you said “it’s salad but it’s not salad” I knew you were going to make something that my mother-in-law calls “salad”🤦🏼\u200d♀️ Yep…jello, marshmallows & cool whip. Feel free to eat my portion 👌',
#       'authorDisplayName': 'Shelly Ballard',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRspujNQodiXANPmpgo2S7Nqa5tTzTDqrEnDA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzMDcnT1vK6XVjKL8Qhq_TQ',
#       'authorChannelId': {'value': 'UCzMDcnT1vK6XVjKL8Qhq_TQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-29T00:25:03Z',
#       'updatedAt': '2021-08-29T00:25:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'F3b-evgh3W8R3uwouPyta7ekePw',
#    'id': 'UgzGvEitHM8pI3Gp6cN4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '73F4tymo1ZHViFmvKwpkjqWCibI',
#      'id': 'UgzGvEitHM8pI3Gp6cN4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Our family ambrosia is made with sour cream instead of cool whip and pudding, so it&#39;s not so sickly sweet and is really creamy. It&#39;s maraschino Cherries, canned pineapple chunks, canned mandarin oranges, marshmallows and sour cream. Mix it all together, add fruit juices to your preference, refrigerate and serve.',
#       'textOriginal': "Our family ambrosia is made with sour cream instead of cool whip and pudding, so it's not so sickly sweet and is really creamy. It's maraschino Cherries, canned pineapple chunks, canned mandarin oranges, marshmallows and sour cream. Mix it all together, add fruit juices to your preference, refrigerate and serve.",
#       'authorDisplayName': 'Kelly Pennington',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRKWir-c0cYpMdfBMxG7SBlC9TNTZEiY7T8PM2a0Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCFrxB807G82dUkNdUObKh_Q',
#       'authorChannelId': {'value': 'UCFrxB807G82dUkNdUObKh_Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-28T21:45:24Z',
#       'updatedAt': '2021-08-28T21:45:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jk2tc3GnI2d995HLNSr8JFho5Xk',
#    'id': 'Ugw3f3diq0SpXxl_n2R4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'N0CY5KLjCLrvIX6PaQO1NnmaZY8',
#      'id': 'Ugw3f3diq0SpXxl_n2R4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Ummm I’m American and can I say I’ve never eaten any of these and nor do I want to try any of them.',
#       'textOriginal': 'Ummm I’m American and can I say I’ve never eaten any of these and nor do I want to try any of them.',
#       'authorDisplayName': 'April Brandi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQdB53Ec_23yuRmxxO2WTMyGlAJM-lp3gD3YA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCXFcePTrPJfHEdzKoSTz4Cw',
#       'authorChannelId': {'value': 'UCXFcePTrPJfHEdzKoSTz4Cw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-28T06:01:23Z',
#       'updatedAt': '2021-08-28T06:01:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'oGi_Lw2ibDMJY8pMc1bdhdQSWdQ',
#    'id': 'Ugw4wd-wwd5nUHGlGZF4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vQc41oqF31v9jhF1svKynk0x3gM',
#      'id': 'Ugw4wd-wwd5nUHGlGZF4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'i have noticed that many American food uses already made snack or side dishes they put cheese, some meat, sauce or reconstruct it and put it in oven',
#       'textOriginal': 'i have noticed that many American food uses already made snack or side dishes they put cheese, some meat, sauce or reconstruct it and put it in oven',
#       'authorDisplayName': 'Shubham Nehate',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQUdyOTOf-P9vBMDzQ7l7y3jrB6F-uqy7GqUkDZ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJRDYThW_T5txM-JKQ9ZdsA',
#       'authorChannelId': {'value': 'UCJRDYThW_T5txM-JKQ9ZdsA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-27T15:48:11Z',
#       'updatedAt': '2021-08-27T15:48:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'IRoLmUolSJ7zmYiORNsTdhKapMU',
#    'id': 'UgxB5Di6c-ykXwOVwB54AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ecy5yg0yRs4tjRs38g_jgh-YaUk',
#      'id': 'UgxB5Di6c-ykXwOVwB54AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I hate ambrosia salad. Its mere existence at a party offends me deeply.<br><br><br>I live in New Orleans, canned food dishes arent super common in general.',
#       'textOriginal': 'I hate ambrosia salad. Its mere existence at a party offends me deeply.\n\n\nI live in New Orleans, canned food dishes arent super common in general.',
#       'authorDisplayName': 'CreoleFaerie',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTWiJSGfDuSlFgqMrKQE5SANy7HcC3Fgf5nZOKV=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UClBKMXqtvBhvbnRELG1z5GQ',
#       'authorChannelId': {'value': 'UClBKMXqtvBhvbnRELG1z5GQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-27T06:39:51Z',
#       'updatedAt': '2021-08-27T06:44:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ARvh_wxzwmmAKUOsr1Ocvs2ozEM',
#    'id': 'Ugy2ee4iZ56TbUMYz-d4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EanFCLOhrcPosGP0vimAAwKuxvs',
#      'id': 'Ugy2ee4iZ56TbUMYz-d4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I did that salad with cherry jello and fresh cherries, wonderful..',
#       'textOriginal': 'I did that salad with cherry jello and fresh cherries, wonderful..',
#       'authorDisplayName': 'Diana Morris',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQsekMOZBavHMiVHIJyRaROf4Ai9cqT05gPZQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9e_HsCSUcQ3301Wv21NnPg',
#       'authorChannelId': {'value': 'UC9e_HsCSUcQ3301Wv21NnPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T23:20:52Z',
#       'updatedAt': '2021-08-26T23:20:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'AAv5t1V0WLy3tlPtwJzFh4kkikM',
#    'id': 'UgyDr67Ajy3ZAWqSrHh4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'diZMQ4wuv-AN462t9yPJDIKK9u8',
#      'id': 'UgyDr67Ajy3ZAWqSrHh4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'We have an adaption of Ambrosia Pudding in New Zealand where it&#39;s known just as Ambrosia. Typically we use berry yoghurt and whipped cream as the base and add chocolate, marshmellows and berries. It&#39;s often served at potlucks and BBQs like in the US, the perfect cold dessert for hot kiwi summers! I encourage everyone to try the NZ version!',
#       'textOriginal': "We have an adaption of Ambrosia Pudding in New Zealand where it's known just as Ambrosia. Typically we use berry yoghurt and whipped cream as the base and add chocolate, marshmellows and berries. It's often served at potlucks and BBQs like in the US, the perfect cold dessert for hot kiwi summers! I encourage everyone to try the NZ version!",
#       'authorDisplayName': 'suzy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLT7UMS8hbKZLDheqHiCf-ftmwJbeM5HSwi8HQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCaNdTp2bOTQkO7kh-iSWftA',
#       'authorChannelId': {'value': 'UCaNdTp2bOTQkO7kh-iSWftA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2021-08-26T22:00:29Z',
#       'updatedAt': '2021-08-26T22:00:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ZJG61gHa--p0sc0MiiXeXqDTofE',
#    'id': 'UgxoJl5Wu8ui3D82ezh4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vTjRXUtRc9UmD36xtn2gqS60MpA',
#      'id': 'UgxoJl5Wu8ui3D82ezh4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Ambrosia salad is so so so much better with sour cream or plain yogurt. Keep in the fridge at least 1hour. The marsmallows fill up and the cream thickens then.',
#       'textOriginal': 'Ambrosia salad is so so so much better with sour cream or plain yogurt. Keep in the fridge at least 1hour. The marsmallows fill up and the cream thickens then.',
#       'authorDisplayName': 'Dominique Kanate',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRWC2v8MXrNyvURloYbUaF8WkVEWblhU1hMGdK6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQutFRSHlUL-l9oq1wmsczw',
#       'authorChannelId': {'value': 'UCQutFRSHlUL-l9oq1wmsczw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T21:02:39Z',
#       'updatedAt': '2021-08-26T21:02:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3ErR_IPpRiAsVvrw5sFlf6MhmNE',
#    'id': 'UgybSIOxnRuAieA1Vat4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iLTiGu46TYTq8wPav5hrswnrmF4',
#      'id': 'UgybSIOxnRuAieA1Vat4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'The things americans call salad, though... wow.',
#       'textOriginal': 'The things americans call salad, though... wow.',
#       'authorDisplayName': 'Dorian M',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLT8nXr9v7xwseZqYFdqkuUDSTv84evTcTEtmBsj8ak=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCxrB3F_eik2FNTss4Awkasg',
#       'authorChannelId': {'value': 'UCxrB3F_eik2FNTss4Awkasg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T18:51:23Z',
#       'updatedAt': '2021-08-26T18:51:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'vCmyva09KvZZ7bZw799uZUh-j-M',
#    'id': 'Ugy3XQbdcDrUf-jcWCN4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OQ5CGBt3n45bFzO1Sxi9fO2zYH4',
#      'id': 'Ugy3XQbdcDrUf-jcWCN4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Watergate salad. Sweet salad. Delicious.',
#       'textOriginal': 'Watergate salad. Sweet salad. Delicious.',
#       'authorDisplayName': 'Diane L',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQtKXAUu8pMYLtrsYzhBGLN7Qe8NAN3XHchr8d2SA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4owSOIgj_oOmRe6ZyR8RQA',
#       'authorChannelId': {'value': 'UC4owSOIgj_oOmRe6ZyR8RQA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T18:40:47Z',
#       'updatedAt': '2021-08-26T18:40:47Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dcnxafbiVXs8EQmWylpliPM1rBg',
#    'id': 'Ugyw9l_oF4z1EfI9Mp94AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'FaKF5RagBvYEnC6yFrHo9PnkOK8',
#      'id': 'Ugyw9l_oF4z1EfI9Mp94AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'My mom mixes a can of rotel(which ever spice level you want) into the tater tot casserole filling and it adds an extra layer of flavor.',
#       'textOriginal': 'My mom mixes a can of rotel(which ever spice level you want) into the tater tot casserole filling and it adds an extra layer of flavor.',
#       'authorDisplayName': 'B.S. H',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR0qrHXHUNSt8R69hZMCR1sGSwFXrI2VAgqJrFX9A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCW24V-9QnvLnmyIzpLn2jGQ',
#       'authorChannelId': {'value': 'UCW24V-9QnvLnmyIzpLn2jGQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T05:01:23Z',
#       'updatedAt': '2021-08-26T05:01:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'H1EsCNfIBG6g6AnEm-rqD78MZh0',
#    'id': 'UgxtfrvSKKDjg5whuet4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ee0bzaltAGZmqxtRvhuV55q9FK8',
#      'id': 'UgxtfrvSKKDjg5whuet4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Have you ever had “Frog Eye Salad”? Talk about not a real salad! I come from a long line of Mormon descendants and this seems to be a super popular recipe, along with funeral potatoes! Let me know if you want more info or a specific recipe!',
#       'textOriginal': 'Have you ever had “Frog Eye Salad”? Talk about not a real salad! I come from a long line of Mormon descendants and this seems to be a super popular recipe, along with funeral potatoes! Let me know if you want more info or a specific recipe!',
#       'authorDisplayName': 'Carly Weggeland',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQM4bDOQB1gYLgIywhwXLVWk-oTFN0wu43HEA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0cSJ-6oC-LDgMpS3P5uwxQ',
#       'authorChannelId': {'value': 'UC0cSJ-6oC-LDgMpS3P5uwxQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T04:15:38Z',
#       'updatedAt': '2021-08-26T04:15:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CoYGaNk309CxPDtW6Jo8Q7rPLGw',
#    'id': 'UgyBJnlbTjO78ElLzft4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uBsPgBey6jLuwbwPwFEbJeSkdP4',
#      'id': 'UgyBJnlbTjO78ElLzft4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I&#39;m from Alabama, everyone&#39;s family always has someone who makes ambrosia or lime jello salad salad for family functions except we call it pink fluff and green fluff. I could never like them myself.',
#       'textOriginal': "I'm from Alabama, everyone's family always has someone who makes ambrosia or lime jello salad salad for family functions except we call it pink fluff and green fluff. I could never like them myself.",
#       'authorDisplayName': 'Tayler Cook',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSotXbmy1nOgMRtsWoX7f1A-aQ13xqqmgL-mx17rEk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCCpPdLJ_ZMIVCCwhJ8WcCdw',
#       'authorChannelId': {'value': 'UCCpPdLJ_ZMIVCCwhJ8WcCdw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T04:13:34Z',
#       'updatedAt': '2021-08-26T04:14:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VLfW9kFhdO_6h6J3TybtgQnWer8',
#    'id': 'UgzjsKu0FCz2Ds-bPOZ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xWw1TgJDxXaL6z4WGFjn20SC0_w',
#      'id': 'UgzjsKu0FCz2Ds-bPOZ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Yes!!!! The strawberry pretzel desert is definitely a pennsylvania thing!! Yumyum.',
#       'textOriginal': 'Yes!!!! The strawberry pretzel desert is definitely a pennsylvania thing!! Yumyum.',
#       'authorDisplayName': 'Laura Miller',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSA3prH1nb_42Qf2iHlt9I3HPGDkYI_v_HJxA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCS6KS9x4V9H892kUMOumX_g',
#       'authorChannelId': {'value': 'UCS6KS9x4V9H892kUMOumX_g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-26T02:54:51Z',
#       'updatedAt': '2021-08-26T02:57:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CnCL1P3iZ6CG1x3oV9A4vmX1rFE',
#    'id': 'UgwcZwiBPta6ALRBYDx4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'aw0UnDD78d8f8-yvwASj6mPATj8',
#      'id': 'UgwcZwiBPta6ALRBYDx4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I love your shirt. Super cute!!!',
#       'textOriginal': 'I love your shirt. Super cute!!!',
#       'authorDisplayName': 'Kristyn Zink',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTZKn7aI65bovOKAUBr37Of3_L7_xfm7Pyfn66imQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCV7yu8QekwDW4Bj7Z_VmO7Q',
#       'authorChannelId': {'value': 'UCV7yu8QekwDW4Bj7Z_VmO7Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-25T22:27:27Z',
#       'updatedAt': '2021-08-25T22:27:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-QoIwN3cCFa9gXCXP_v9fU8Bb4c',
#    'id': 'UgyJ7HYkGqZF6oETDYJ4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NWNnADSF2TE98l3lfxMZguoDRz8',
#      'id': 'UgyJ7HYkGqZF6oETDYJ4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'We call the ambrosia salad frog-eye salad!',
#       'textOriginal': 'We call the ambrosia salad frog-eye salad!',
#       'authorDisplayName': 'Madeleine Christensen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRKAw491C-7k4z-z5Dhd0bPnCIkHO2N2GPMdp_i=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCM_HOKuurwIaBJsmRH-oc_g',
#       'authorChannelId': {'value': 'UCM_HOKuurwIaBJsmRH-oc_g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-25T13:37:35Z',
#       'updatedAt': '2021-08-25T13:37:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'AYmuXxaYwC9dsci1c_S_K7u76HM',
#    'id': 'Ugy6odYf5kwojc23vFR4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'v4ubZBQ8xfpMh-QPMVCWq1EM9p0',
#      'id': 'Ugy6odYf5kwojc23vFR4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Beryl, would you consider doing an episode on international pregnancy and postpartum foods? I just found your channel and am in love, and I’m also pregnant with my second baby. The pregnancy literature in the US has a lot of food rules that other cultures may not subscribe to, and I’m curious about what other people think about the kind of food that nourishes a mother and her baby. I also think it would be great to dive into the traditions around these foods, since I imagine these would often be dishes prepared by mothers/sisters/aunts/grandmothers for a new mom. Thanks!!',
#       'textOriginal': 'Beryl, would you consider doing an episode on international pregnancy and postpartum foods? I just found your channel and am in love, and I’m also pregnant with my second baby. The pregnancy literature in the US has a lot of food rules that other cultures may not subscribe to, and I’m curious about what other people think about the kind of food that nourishes a mother and her baby. I also think it would be great to dive into the traditions around these foods, since I imagine these would often be dishes prepared by mothers/sisters/aunts/grandmothers for a new mom. Thanks!!',
#       'authorDisplayName': 'Megan Geiger',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTvinZa2Wlj6E1LrYns9lyFqOTalJUU0vPwzw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC28UmN6mw88zqt5T1qG1dlw',
#       'authorChannelId': {'value': 'UC28UmN6mw88zqt5T1qG1dlw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-25T02:15:10Z',
#       'updatedAt': '2021-08-25T02:15:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NQkQDIhblNiQMcMdXOQtwHe2Bbk',
#    'id': 'Ugxb0Py3uJivkrsaOG94AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ASJLkK6HGdTRV2Pp_UOOPwCtk2o',
#      'id': 'Ugxb0Py3uJivkrsaOG94AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'But whyyyy are they all called salads??',
#       'textOriginal': 'But whyyyy are they all called salads??',
#       'authorDisplayName': 'emily k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLREWKY0X_LjQh1cME0qxEFDZC1dXlPJhzUK6g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwaRIC17zef9zjHqEWEyudg',
#       'authorChannelId': {'value': 'UCwaRIC17zef9zjHqEWEyudg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-25T00:19:46Z',
#       'updatedAt': '2021-08-25T00:19:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VrNgv8vIa8uGgqv4AYKLPxu3I0M',
#    'id': 'UgxhdGd7miP-P2OstMN4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5sp7WtdwGeWzb-VO631fSQDXLyw',
#      'id': 'UgxhdGd7miP-P2OstMN4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'sorry but there is no chance that that dude is from north dakota..',
#       'textOriginal': 'sorry but there is no chance that that dude is from north dakota..',
#       'authorDisplayName': 'Doms',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQi34Z3dYWVz3KBXBEiCnZZqJW9-J9v6g0qcQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCc9HRszMR9AWWd8zsGd_byQ',
#       'authorChannelId': {'value': 'UCc9HRszMR9AWWd8zsGd_byQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-24T04:07:30Z',
#       'updatedAt': '2021-08-24T04:07:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uogIpQLAGuhsjwZMXw0Ts71grMM',
#    'id': 'UgzvKLPZtAyJAOH2joB4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mUp7H3Tp93ktbUWcCGRXRB_JwFA',
#      'id': 'UgzvKLPZtAyJAOH2joB4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Regional to So. Cal: Fish Tacos.',
#       'textOriginal': 'Regional to So. Cal: Fish Tacos.',
#       'authorDisplayName': 'Le An',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR3SDubPN5v6iSpB6DIuVgRfZf1SzdCGH1f13uexw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCrThfspDHpDIA5WgOsVOt5w',
#       'authorChannelId': {'value': 'UCrThfspDHpDIA5WgOsVOt5w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-24T01:23:23Z',
#       'updatedAt': '2021-08-24T01:23:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'USmLrSnCUV3pgG6sO5csPULp7_Q',
#    'id': 'Ugw785na5kGDXwHSB0p4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ZXtxanlQ7O2ORZk_PZUvOCMk2mA',
#      'id': 'Ugw785na5kGDXwHSB0p4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Ambrosia salad. Nix the pudding. Nix the Cool Whip. Use sour cream.',
#       'textOriginal': 'Ambrosia salad. Nix the pudding. Nix the Cool Whip. Use sour cream.',
#       'authorDisplayName': 'richcianci',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTjZWKunzfjsE-UtNu0XX0-4C3_pAP8kDPtuQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqin_sTXq7OZSYqdnPgR2Nw',
#       'authorChannelId': {'value': 'UCqin_sTXq7OZSYqdnPgR2Nw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-23T02:15:23Z',
#       'updatedAt': '2021-08-23T02:30:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'wVF83MEnNvUp7xYKgc-39dNgi-8',
#    'id': 'UgzFapa_azwP1H54KtV4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'sxDV3gByXQ0NKZ4gSWXu-pjmaa4',
#      'id': 'UgzFapa_azwP1H54KtV4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'My medication kicked in mid way, and now I can only focus on the music.',
#       'textOriginal': 'My medication kicked in mid way, and now I can only focus on the music.',
#       'authorDisplayName': 'Jane & John Doh',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQt0mz_UzHAwRpt_uDRv-LfvPza7e2taI0weA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQZtueV2ZXFnl-31fXWKJLQ',
#       'authorChannelId': {'value': 'UCQZtueV2ZXFnl-31fXWKJLQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-08-23T01:55:46Z',
#       'updatedAt': '2021-08-23T01:55:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bKNGtgZNuT479HA0XiC8tez0I3k',
#    'id': 'UgzU0y1wQ3C7jWwJDFV4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GCEXjeOBM_9qIWZXd--gqYo0Khk',
#      'id': 'UgzU0y1wQ3C7jWwJDFV4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'The Lime Jello salad was always served at Christmas at my house growing up.',
#       'textOriginal': 'The Lime Jello salad was always served at Christmas at my house growing up.',
#       'authorDisplayName': 'Lisa Henderson',
# ...
#       'publishedAt': '2021-07-30T04:08:12Z',
#       'updatedAt': '2021-07-30T04:19:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4bXgMLCofLI5mLIoDIUqTiKaBjs',
#    'id': 'UgwOW8uW9jDM_Fexusx4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'IMBgP3bpKzgfnyf9yKuQRrkvs9s',
#      'id': 'UgwOW8uW9jDM_Fexusx4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'American food makes be feel better about British food',
#       'textOriginal': 'American food makes be feel better about British food',
#       'authorDisplayName': 'Dan Richmond',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRPrDEhAsqx2KVFmIeM1z0fwU4mMU2vlmbQEw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqHuOE4Mv-a3jx6c_wPezDA',
#       'authorChannelId': {'value': 'UCqHuOE4Mv-a3jx6c_wPezDA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-29T22:12:23Z',
#       'updatedAt': '2021-07-29T22:12:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BcGI5tcHQET9iSDtbpZI1AVO-8E',
#    'id': 'Ugxs5pbjcqFkq6c_YG54AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'A9P3Y5QDLBW9nfMG00qICwBTMNA',
#      'id': 'Ugxs5pbjcqFkq6c_YG54AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'I don’t like ambrosia salad but I love my grandmother’s Pink “Salad”. We eat it for dessert (and sometimes would sneak for breakfast), so it’s very much a sweet dish. Here is the recipe:<br>One tub of whipped cream<br>One small can of condensed milk <br>One can of strawberry pie filling<br>One can of crushed pineapple (not drained)<br>Two small cans of mandarin oranges (drained)<br>One cup of marshmallows<br>Chopped pecans on top (I skip this)<br>Mix all together and chill for about an hour. Enjoy!',
#       'textOriginal': 'I don’t like ambrosia salad but I love my grandmother’s Pink “Salad”. We eat it for dessert (and sometimes would sneak for breakfast), so it’s very much a sweet dish. Here is the recipe:\nOne tub of whipped cream\nOne small can of condensed milk \nOne can of strawberry pie filling\nOne can of crushed pineapple (not drained)\nTwo small cans of mandarin oranges (drained)\nOne cup of marshmallows\nChopped pecans on top (I skip this)\nMix all together and chill for about an hour. Enjoy!',
#       'authorDisplayName': 'Taylor',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRF12mlQOsBNSJ6qr3uU71vF-XXJ-ULza7sVvxk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCAkiCovCZnYMgY-Q8noKMXQ',
#       'authorChannelId': {'value': 'UCAkiCovCZnYMgY-Q8noKMXQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-29T17:39:45Z',
#       'updatedAt': '2021-07-29T17:39:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'R205TxOmlwhJf2GqydgA6Aknmz0',
#    'id': 'Ugz_wBPQxVlemjNnd5h4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uyrzqrJXrJ9WAiUD_dycQETEIno',
#      'id': 'Ugz_wBPQxVlemjNnd5h4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Tatortots while comforting are by no means fancy. Tator Tots are really just a nugget form of hash browns',
#       'textOriginal': 'Tatortots while comforting are by no means fancy. Tator Tots are really just a nugget form of hash browns',
#       'authorDisplayName': 'Cloud Begner',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRcVMUW_fXJRJCU2-9Q42BOlKPQUliLbEBvIkJc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCYXI4tIJvarEgjv1oc3tfzw',
#       'authorChannelId': {'value': 'UCYXI4tIJvarEgjv1oc3tfzw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-29T14:34:51Z',
#       'updatedAt': '2021-07-29T14:34:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ge0opSaeOFd3imL90NGsDIw9aLI',
#    'id': 'UgytM2wYwOafEGPiLIR4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mMBsrnsO2T-bC4jn8PMFqINxf8U',
#      'id': 'UgytM2wYwOafEGPiLIR4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Idk which person thought it was a good idea to make all those weird salads man.. 🤨',
#       'textOriginal': 'Idk which person thought it was a good idea to make all those weird salads man.. 🤨',
#       'authorDisplayName': 'Anna Marie',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSW7rDMz4FozNi70pizJaxNgBFmd3MYwUHY421w9w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCo2_0At8Z0zsGh5D6NSqXhw',
#       'authorChannelId': {'value': 'UCo2_0At8Z0zsGh5D6NSqXhw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-29T03:48:48Z',
#       'updatedAt': '2021-07-29T03:48:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dtwG4eTrzi_1TrVm3_8MLkR_UV0',
#    'id': 'UgyNZ0jBhSay_oH0R0x4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vmx_i-AwGJWyUKMeTYJEYfVX2_U',
#      'id': 'UgyNZ0jBhSay_oH0R0x4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'the amount of proccesed foods in this video that I haven`t even heard of before...',
#       'textOriginal': 'the amount of proccesed foods in this video that I haven`t even heard of before...',
#       'authorDisplayName': 'Lily k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQFB6nBaMeTMTEPp9butUXsmoL3o9w5VLQBbRE26A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCE6YohxI3vB3qtELYHlDEgg',
#       'authorChannelId': {'value': 'UCE6YohxI3vB3qtELYHlDEgg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-27T18:39:06Z',
#       'updatedAt': '2021-07-27T18:39:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yfI3jjfw9DEnirHaY28H9NeWkrs',
#    'id': 'UgxpYIQpWYNTG6bXQSV4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oKIarRjs3-QC90bACIr6bQqIn3o',
#      'id': 'UgxpYIQpWYNTG6bXQSV4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'In South Dakota we added green beans to the tater tot casserole. We also would change out the cream of mushroom for cream of tomato for more of like a ketchup taste. Both are great! Best comfort food.',
#       'textOriginal': 'In South Dakota we added green beans to the tater tot casserole. We also would change out the cream of mushroom for cream of tomato for more of like a ketchup taste. Both are great! Best comfort food.',
#       'authorDisplayName': 'Liz O.',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLThOm-jmZClduq9YozbdsZA5dNttuLWyNUYXK3u=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9tcCpj02rQmVzofACGzW1Q',
#       'authorChannelId': {'value': 'UC9tcCpj02rQmVzofACGzW1Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-26T23:02:39Z',
#       'updatedAt': '2021-07-26T23:02:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UR2Vd4iA2WYunm3Kx6hYLdqUr_U',
#    'id': 'UgymwfwJQefCHkqVrt14AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Vz7sLCaisefWIyNsKYFFeN95lZE',
#      'id': 'UgymwfwJQefCHkqVrt14AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'New Zealand has Ambrosia too, but we do not consider it a salad. It&#39;s just dessert. Our Ambrosia is yoghurt based... Apart from fruit salad, salad is savoury. We don&#39;t have Cool Whip in NZ - sadly 😔 if you&#39;d like the Ambrosia recipe I&#39;ll gladly write it out for you. The thing about this ambrosia is that the yoghurt cuts the sweetness a bit so it&#39;s not so tooth jingling sweet.',
#       'textOriginal': "New Zealand has Ambrosia too, but we do not consider it a salad. It's just dessert. Our Ambrosia is yoghurt based... Apart from fruit salad, salad is savoury. We don't have Cool Whip in NZ - sadly 😔 if you'd like the Ambrosia recipe I'll gladly write it out for you. The thing about this ambrosia is that the yoghurt cuts the sweetness a bit so it's not so tooth jingling sweet.",
#       'authorDisplayName': 'Deidre Cruickshank',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSYvWfhbx5SLHx7p9Q1imKWokDA4FlnWSN1ptmU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJXjWbUTSU73lGCXZwiGUuQ',
#       'authorChannelId': {'value': 'UCJXjWbUTSU73lGCXZwiGUuQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-26T21:19:44Z',
#       'updatedAt': '2021-08-30T15:12:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '18zXLLd1gPN0AmX5A2BEKtZZYVQ',
#    'id': 'UgzILytmkKWDyG1wjHh4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'v16r9ThoDeiEHy0besXgbwsfACU',
#      'id': 'UgzILytmkKWDyG1wjHh4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Whaaaaaaaattttt don&#39;t put pineapple in pretzel jello! Frozen strawberries only! And you do half cream cheese and half coolwhip! We always just used a rolling pin to get pretzel chunks. I love pretzel jello :) Never had the lime salad till I had Thanksgiving in KY with my partner. His family has lime jello at the holidays and I just don&#39;t like it lol<br><br>Love that like most of these are quirky and vintage recipes, lol. They apparently stand the test of time?',
#       'textOriginal': "Whaaaaaaaattttt don't put pineapple in pretzel jello! Frozen strawberries only! And you do half cream cheese and half coolwhip! We always just used a rolling pin to get pretzel chunks. I love pretzel jello :) Never had the lime salad till I had Thanksgiving in KY with my partner. His family has lime jello at the holidays and I just don't like it lol\n\nLove that like most of these are quirky and vintage recipes, lol. They apparently stand the test of time?",
#       'authorDisplayName': 'Miss MJ',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQnX8GjkvUfAqFk4veg-C4fa0zbOXMjRQiX1bGfaQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1-KZHZ9etdBtJwABdSYNgg',
#       'authorChannelId': {'value': 'UC1-KZHZ9etdBtJwABdSYNgg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-26T17:02:20Z',
#       'updatedAt': '2021-07-26T17:02:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0rhEaEVMPiB2xHHjg0uXPw0fNWQ',
#    'id': 'UgwfaWFoC1cmz6-jef54AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bPEffia-8duYXbzpyhLRA1s9-Bo',
#      'id': 'UgwfaWFoC1cmz6-jef54AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Wait…in the background…is that the original classical music that is featured in “back that azz up?”',
#       'textOriginal': 'Wait…in the background…is that the original classical music that is featured in “back that azz up?”',
#       'authorDisplayName': 'Tj Plott',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLT3MCu9VGHSOXfzQY6SfnZmJdUwpTCn5pl3yg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQxXvlRWZXeLIM2nyRJKnUA',
#       'authorChannelId': {'value': 'UCQxXvlRWZXeLIM2nyRJKnUA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-26T01:44:11Z',
#       'updatedAt': '2021-07-26T01:44:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ty9DNj69TBcLFZth0piArkP9Rgk',
#    'id': 'UgwdbhAI-JfrXWqCaQN4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'CuV5kasTUTiFcO2vLOLFKeWR0hw',
#      'id': 'UgwdbhAI-JfrXWqCaQN4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'Why are these things called salad?',
#       'textOriginal': 'Why are these things called salad?',
#       'authorDisplayName': 'liten kanin',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR63ZCN6xEhyf1sHMQcNvoQs01kVgCs31GaFKM-ew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMo-5inzHVHlNJ-uw-P-EJg',
#       'authorChannelId': {'value': 'UCMo-5inzHVHlNJ-uw-P-EJg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-25T23:58:56Z',
#       'updatedAt': '2021-07-25T23:58:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EjTh7RfSHIU8kZQcm0elPjiHfmM',
#    'id': 'UgwjRTXmW8hu184dpXh4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '92TKsJ0Y1aRarbMKRPpq1n9VgQk',
#      'id': 'UgwjRTXmW8hu184dpXh4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'you can also add corn or green beans to the tater tot hot dish.  gotta get them veggies in',
#       'textOriginal': 'you can also add corn or green beans to the tater tot hot dish.  gotta get them veggies in',
#       'authorDisplayName': 'Tara Hansen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQv64mhnTCyuvum3rS165pHng7aO8h8wwvXepECeQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCt1xlhzDzZPViI9xjPDMSIA',
#       'authorChannelId': {'value': 'UCt1xlhzDzZPViI9xjPDMSIA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-25T22:35:21Z',
#       'updatedAt': '2021-07-25T22:35:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LFJD9ltIzSd0b3WPC7_PGHAecMc',
#    'id': 'Ugyr5Qu63RnMjd2uxId4AaABAg',
#    'snippet': {'videoId': 'qy4OmeTuNQ8',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0rS86lLu0gjCMbPPL6KUcnhZ4dA',
#      'id': 'Ugyr5Qu63RnMjd2uxId4AaABAg',
#      'snippet': {'videoId': 'qy4OmeTuNQ8',
#       'textDisplay': 'My wife&#39;s family has multiple jello salads, the  orange jello with carrots is my least favorite... to be honest they are all pretty awful.',
#       'textOriginal': "My wife's family has multiple jello salads, the  orange jello with carrots is my least favorite... to be honest they are all pretty awful.",
#       'authorDisplayName': 'Chris Strunk',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSW4S6v3TIBSbIGGGcz2cj6vXdccG7POdfJ9w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCaq_8KEvkQ61x8TInoSjavQ',
#       'authorChannelId': {'value': 'UCaq_8KEvkQ61x8TInoSjavQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2021-07-25T20:45:35Z',
#       'updatedAt': '2021-07-25T20:45:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
for item in res['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'], "\n")
# Out:
# I realize a lot of you are missing some important context, I made this video talking about why a lot of these dishes are, the way they are: <a href="https://www.youtube.com/watch?v=Dbi3EG4r8kM&amp;t=">https://www.youtube.com/watch?v=Dbi3EG4r8kM&amp;t=</a>
#
# The lime jello salad is Watergate salad, originated at the Watergate Hotel (yes, same one as Nixon&#39;s scandal).
#
# Your first dish of the video just so happens to be what I&#39;m making tonight for dinner.<br>HOWEVER! I grew up with my mom adding corn to it, and I can&#39;t have it without the corn. without the corn, it reminds me of that hash stuff in a can that I&#39;ve always hated.<br>I&#39;ve also never had this with ketchup before..but my boyfriend.. he grew up having it without corn, and with ketchup!
#
# The jellos salads come in so many different recipes and names. My mom made what she called ambrosia and it was a lime jellos salad ingredients slightly different than the one in this one.
#
# Never had an armadillo egg but jalapeño poppers where I live are made almost the same leave out the sausage and no garlic.  Wrap in bacon and then oven or grill.
#
# Strawberry pretzel dessert is something I do love but have only made once. My husband loves each of these ingredients, so I was so excited to make it for him - but he didn’t like it at all. 😂 What?  Really?  How can you not love it? 🤷🏻‍♀️
#
# I love lime jello salad - it brings back good memories
#
# You missed “cookie salad”!
#
# Did that man just call tater tots &quot;fancy&quot;?<br>🤣🤣
#
# You should definitely try Funeral Potatoes. I live in Idaho, USA and had never heard of this until I moved here. But if you like savory potato dishes - oh my gosh - it&#39;s delish!
#
# That&#39;s definitely not the lime jello salad my grandma made. I&#39;ll have to find the recipe, but it was a favorite of ours! She made a strawberry jello version, too.
#
# Ooh ooh! Do elephant ears!!
#
# My family does lime jello salad as well! Different but mostly the same
#
# Holy shit I love your shirt (the one with the cat collar at the beginning of the video)
#
# I can&#39;t believe amercians still buy and eat cool whip. It is basically just sugar and fat hold together with chemicals that cause chronical kidney disease - the reason why this porduct is banned in germany. Don&#39;t use it. Do yourself a favour and whip actual cream. Tastes better and is not so dangerous.
#
# my dad loves strawberry pretzel salad!!! he’s from Western PA
#
# As soon as you said “it’s salad but it’s not salad” I knew you were going to make something that my mother-in-law calls “salad”🤦🏼‍♀️ Yep…jello, marshmallows &amp; cool whip. Feel free to eat my portion 👌
#
# Our family ambrosia is made with sour cream instead of cool whip and pudding, so it&#39;s not so sickly sweet and is really creamy. It&#39;s maraschino Cherries, canned pineapple chunks, canned mandarin oranges, marshmallows and sour cream. Mix it all together, add fruit juices to your preference, refrigerate and serve.
#
# Ummm I’m American and can I say I’ve never eaten any of these and nor do I want to try any of them.
#
# i have noticed that many American food uses already made snack or side dishes they put cheese, some meat, sauce or reconstruct it and put it in oven
#
# I hate ambrosia salad. Its mere existence at a party offends me deeply.<br><br><br>I live in New Orleans, canned food dishes arent super common in general.
#
# I did that salad with cherry jello and fresh cherries, wonderful..
#
# We have an adaption of Ambrosia Pudding in New Zealand where it&#39;s known just as Ambrosia. Typically we use berry yoghurt and whipped cream as the base and add chocolate, marshmellows and berries. It&#39;s often served at potlucks and BBQs like in the US, the perfect cold dessert for hot kiwi summers! I encourage everyone to try the NZ version!
#
# Ambrosia salad is so so so much better with sour cream or plain yogurt. Keep in the fridge at least 1hour. The marsmallows fill up and the cream thickens then.
#
# The things americans call salad, though... wow.
#
# Watergate salad. Sweet salad. Delicious.
#
# My mom mixes a can of rotel(which ever spice level you want) into the tater tot casserole filling and it adds an extra layer of flavor.
#
# Have you ever had “Frog Eye Salad”? Talk about not a real salad! I come from a long line of Mormon descendants and this seems to be a super popular recipe, along with funeral potatoes! Let me know if you want more info or a specific recipe!
#
# I&#39;m from Alabama, everyone&#39;s family always has someone who makes ambrosia or lime jello salad salad for family functions except we call it pink fluff and green fluff. I could never like them myself.
#
# Yes!!!! The strawberry pretzel desert is definitely a pennsylvania thing!! Yumyum.
#
# I love your shirt. Super cute!!!
#
# We call the ambrosia salad frog-eye salad!
#
# Beryl, would you consider doing an episode on international pregnancy and postpartum foods? I just found your channel and am in love, and I’m also pregnant with my second baby. The pregnancy literature in the US has a lot of food rules that other cultures may not subscribe to, and I’m curious about what other people think about the kind of food that nourishes a mother and her baby. I also think it would be great to dive into the traditions around these foods, since I imagine these would often be dishes prepared by mothers/sisters/aunts/grandmothers for a new mom. Thanks!!
#
# But whyyyy are they all called salads??
#
# sorry but there is no chance that that dude is from north dakota..
#
# Regional to So. Cal: Fish Tacos.
#
# Ambrosia salad. Nix the pudding. Nix the Cool Whip. Use sour cream.
#
# My medication kicked in mid way, and now I can only focus on the music.
#
# The Lime Jello salad was always served at Christmas at my house growing up.
#
# We do strawberry pretzel salad for every holiday. I even make a version using frozen red raspberries. It is so good.
#
# <a href="https://www.youtube.com/watch?v=qy4OmeTuNQ8&amp;t=2m35s">2:35</a> &quot;But the cool thing about these dishes is they were made to bring people together—&quot;<br>me: oh, like parties!<br>&quot;Like a funeral&quot;<br>me:.....oh okay, I guess—I guess that works too
#
# There are so many other foods that different states have too. When I moved to Utah I had never heard of Frog Eye Salad (lol yup one of those not salad but more dessert salads.) Funeral potatoes and Mormon muffins. I&#39;m wondering why cool whip is in a lot of these &#39;salads&#39;??
#
# My family&#39;s version of the lime salad was just lime jello with crushed pineapple added. Which I would highly recommend trying since I love it so much, but like you can NOT get into the creamy &#39;chunky&#39; version a lot of people make lol
#
# I like pecans in my ambrosia
#
# My family (in western SD) eats strawberry pretzel salad for Thanksgiving every year, other than meat and potatoes, it&#39;s the only dish we all agree has to be in the table!
#
# Pittsburgh style sandwiches/salad!
#
# you look so apologetic not liking a dish it&#39;s very sweet (but completely unnecessary ?)
#
# how is the last one a salad not a cheesecake
#
# She doesn’t lie it but keeps eating It lol
#
# The sweet salads need pretzels
#
# I feel like the fact that majority of the ingredients came out of a bag/can is the most American thing in this video 😂😂
#
# Can we have a regional french fry episode?<br><br>A truly regional New Jersey dish is the diner classic Disco Fries.  This a poutine adjacent dish.  It is a classic late night college meal when you only had a little cash and you shared a plate of these with your roommate in a 24 hour in North Jersey.  You won&#39;t see these on menus in South Jersey though.<br><br>The South Jersey french fry classic would go to the Mega Fry.  This is typically a pizza place appetizer consisting of fries (I like a thinner fry) topped with various cheeses (cheddar, Monterey jack, mozzarella), green onion and bacon.  Ranch dressing is sometimes drizzled on the top or provided for dipping.<br><br>Philadelphia french fry would be the Crab Fry.  These were made popular by the local chain Chickie &amp; Pete&#39;s.  They consist of skinny crinkle fries dusted with Old Bay and served with a magical American cheese sauce.  I will gladly wait in line for hour and hand over my 14 dollars for a tub of these at a Phillies game.
#
# You think this version of ambrosia is heavy! This is the first variation of ambrosia salad that i&#39;ve seen that doesn&#39;t contain mayonnaise or sour cream.
#
# In San Antonio the armadillo egg is known as a Texas Twinkie.
#
# I&#39;m not surprised that the ambrosia salad is similar to Philippines&#39; buko salad. The latter was most likely introduced to the islands during the American occupation. I like buko salad though so although the marshmallow is throwing me off, imma give this a try 😆
#
# Scandinavian.. or Norwegian.. Norway is in Scandinavia x)
#
# I live on a strawberry farm in NC. The strawberry pretzel salad we just call a pretzel tart. My family loves it! The sweet/creamy/salt is amazing.
#
# Welcome to America, where every family has a jello salad recipe.  Always served during the holidays, although few remember why anymore.
#
# I love that “multicultural” can be as inclusive as both Norwegian <b>and</b> German.  That said, it was SCANDALOUS when my Danish and Swedish great-greats married in the late 19th century.
#
# Much better with the strawberries tho
#
# Minnesotan here… he forgot the green beans<br>And corn in that hot dish.
#
# I can’t help but assume that most American cook books are written by 6 year olds. It’s the only possible explanation.
#
# Michigan cherry chicken salad. So good!!
#
# Please tell me where those black snake earrings are from, I need them in my life desperately.
#
# I really enjoyed this one!  If you do another regional American recipe video, lemme know, I have a few for you! They are regional, with a capital R.
#
# My hubs grew up on Tater tot casserole.... I had never heard of it. This is his very favorite.   His is ground beef, cream of mushroom canned mix and NO VEGETABLES then packaged potatoes.  Not a fan... I make this for him WITH vegetables, homemade mushroom gravy with sour cream.  Then the tater tots.  Hubs would eat it... but when I got sick, he made his version and the kids like his better.... LOL.<br><br>Oh, fruit salad... I love this with more fruit and less of the sauce with real whipped cream, no koolwhip.  I have never figured out if Koolwhip is actually food.    The jello fluff I grew up with but we never added the nuts.  Now, strawberry pretzel salad is the BOMB, I just don&#39;t get it very much. Again, real whip cream and my fruit to jello ratio is much higher on the fruit range.
#
# I absolutely love ambrosia salad but my family doesn’t add pudding because thats a bit too sweet, for extra flavour we use colourful marshmallows instead of white ones!
#
# You are so cute! So happy to come across your channel! Great cooking ideas!
#
# <a href="https://www.youtube.com/watch?v=qy4OmeTuNQ8&amp;t=6m24s">6:24</a> she didn’t even sear it first. She went straight into the oven lol
#
# ambrosia salad sounds so 1950s. so does lime jello salad. it sounds like something i&#39;d love to make when i&#39;m cranky and have too low blood sugar to make anything.
#
# Tater tots are a fancy potato 🤣🤣 served at sonic
#
# Coming from Wisconsin I sooo wish you had tried Lime Jello Desert. Essentially the same ingredients but cut the cottage cheese and marshmellows, but lay the cream and lime jello mixture over an Oreo pie crust and chill in the fridge to serve cold.
#
# With tater tot casserole, I make mine that same way, but I add onion while the hamburger is cooking, and then I add corn and green beans with the cream of mushrooms. 10/10<br>Oh, and I am also from North Dakota.
#
# Funeral potatoes; lime jello with shredded carrots
#
# Sadly this shows how much processed foods is a staple in the American diet.
#
# can we talk about her cat collar on her button up? like it so cute
#
# why american people love jello so much tho
#
# MUtliCulTuRal - 3 types of Nth European!
#
# My family does a different version of the lime jello salad.  We solidify the jello with pineapple bits (I halve the water so it&#39;s firmer later). Then mix in the cottage and whipped cream.  Chill again.  No marshmallows or nuts.  This makes me so happy we aren&#39;t the only ones who love this stuff, especially for thanksgiving!!! I&#39;ve done the strawberry pretzel salad with raspberry instead.  Excellent!
#
# The Ambrosia &amp; Lime salads are delicious. Thank you...
#
# OMG put that ketchup away! You need the casserole unadulterated! We used to add French style green beans as well.
#
# Love your videos, just discovered you yesterday and I have watched so many videos already! Also your earrings are EVERYTHING! &lt;333
#
# You went to all that work and then pull out bottled ranch? Yikes! Homemade takes about 90 seconds to make!
#
# My mother loved ambrosia salad....I didn&#39;t know it was a regenal dish. Strawberry pretzel salad seemed very common in western PA !
#
# My family also has a traditional lime-pear salad that I&#39;ve never touched in nearly 3 decades.  I had the feeling that lime jello salad would get about that reaction.
#
# Every Thanksgiving my grandmother would make her wierd salad. It had pistachio pudding, pine apple, marshmallows, walnuts... I always dreaded it because my parents would make me have a bowl. Which I never wanted...
#
# Those salad sounds and looks like from the 1050&#39;s and 60&#39;s
#
# My family in Oregon (this dish only known from my moms side) has always made the  Lime Jello Salad for Thanksgiving... however they have always omitted the marshmallows and nuts and i think cream cheese was added in addition.  I don&#39;t know if i&#39;d like it with the weird added textures.  I&#39;m not a fan of sweet things so I usually avoid it as an adult.  (There&#39;s no mayo in it either... looking up weird recipes online btw,  yuck)
#
# American food makes be feel better about British food
#
# I don’t like ambrosia salad but I love my grandmother’s Pink “Salad”. We eat it for dessert (and sometimes would sneak for breakfast), so it’s very much a sweet dish. Here is the recipe:<br>One tub of whipped cream<br>One small can of condensed milk <br>One can of strawberry pie filling<br>One can of crushed pineapple (not drained)<br>Two small cans of mandarin oranges (drained)<br>One cup of marshmallows<br>Chopped pecans on top (I skip this)<br>Mix all together and chill for about an hour. Enjoy!
#
# Tatortots while comforting are by no means fancy. Tator Tots are really just a nugget form of hash browns
#
# Idk which person thought it was a good idea to make all those weird salads man.. 🤨
#
# the amount of proccesed foods in this video that I haven`t even heard of before...
#
# In South Dakota we added green beans to the tater tot casserole. We also would change out the cream of mushroom for cream of tomato for more of like a ketchup taste. Both are great! Best comfort food.
#
# New Zealand has Ambrosia too, but we do not consider it a salad. It&#39;s just dessert. Our Ambrosia is yoghurt based... Apart from fruit salad, salad is savoury. We don&#39;t have Cool Whip in NZ - sadly 😔 if you&#39;d like the Ambrosia recipe I&#39;ll gladly write it out for you. The thing about this ambrosia is that the yoghurt cuts the sweetness a bit so it&#39;s not so tooth jingling sweet.
#
# Whaaaaaaaattttt don&#39;t put pineapple in pretzel jello! Frozen strawberries only! And you do half cream cheese and half coolwhip! We always just used a rolling pin to get pretzel chunks. I love pretzel jello :) Never had the lime salad till I had Thanksgiving in KY with my partner. His family has lime jello at the holidays and I just don&#39;t like it lol<br><br>Love that like most of these are quirky and vintage recipes, lol. They apparently stand the test of time?
#
# Wait…in the background…is that the original classical music that is featured in “back that azz up?”
#
# Why are these things called salad?
#
# you can also add corn or green beans to the tater tot hot dish.  gotta get them veggies in
#
# My wife&#39;s family has multiple jello salads, the  orange jello with carrots is my least favorite... to be honest they are all pretty awful.

# %%
def get_video_stats(video_ids):
    stats= []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id = ','.join(video_ids[i:i+50]),
                              part = 'statistics').execute()
        
        stats += res['items']
        
    return stats

# %%
video_ids = list(map(lambda x : x['snippet']['resourceId']['videoId'], videos))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-289ca5cfb265> in <module>
# ----> 1 video_ids = list(map(lambda x : x['snippet']['resourceId']['videoId'], videos))
#
# NameError: name 'videos' is not defined

# %%
def all_comments(video_id):
    
    comments = []
    next_page_token = None
    
    while 1:
        res = youtube.commentThreads().list(videoId = video_id,
                                           part = 'snippet',
                                           maxResults = 100,
                                           pageToken = next_page_token).execute()
        
        comments += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
        return comments

# %%
#['snippet']['topLevelComment']['snippet']['textDisplay']

# %%
comments = all_comments('qy4OmeTuNQ8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-fe7229f9a689> in <module>
# ----> 1 comments = all_comments('qy4OmeTuNQ8')
#
# <ipython-input-9-c2230b78905e> in all_comments(video_id)
#      10                                            pageToken = next_page_token).execute()
#      11
# ---> 12         comments += res['items']['snippet']['topLevelComment']['snippet']['textDisplay']
#      13         next_page_token = res.get('nextPageToken')
#      14
#
# TypeError: list indices must be integers or slices, not str

# %%
len(comments)

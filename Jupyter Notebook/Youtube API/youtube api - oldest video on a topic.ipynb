# %%
api_key = "AIzaSyBcFYRif86FKOm99sfuCHu9y0nvhTrDy_0"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
from datetime import datetime

# %%
start_time = datetime(year = 2007, month = 1, day = 1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year = 2008, month = 1, day = 1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
res = youtube.search().list(part = 'snippet',
                            q = 'shereshewsky',
                            maxResults = 50,
                            type = 'video',
                            publishedAfter = start_time,
                            publishedBefore = end_time).execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'LgrKw2VNtSlyda4GDccYrq0eHfc',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 12, 'resultsPerPage': 9},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '9U863G3ma9ve5Clw9-Rq7fGYvd0',
#    'id': {'kind': 'youtube#video', 'videoId': '3e8UypFobTQ'},
#    'snippet': {'publishedAt': '2007-08-01T14:27:48Z',
#     'channelId': 'UCfug8DWAetDjUYux3dcX5Lg',
#     'title': 'Jerry Shereshewsky',
#     'description': 'Farewell to Yahoo! by Jon Cronin.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3e8UypFobTQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3e8UypFobTQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3e8UypFobTQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jon Cronin',
#     'liveBroadcastContent': 'none',
# ...

# %%
for item in sorted(res['items'], key= lambda x:x['snippet']['publishedAt']):
    print(item['snippet']['title'], item['id']['videoId'], item['snippet']['publishedAt'], sep = ' ; ')
# Out:
# Mr. Jon Cronin on A Billboard in Times Square ; lq6qTlao3Wc ; 2007-01-24T23:14:57Z
# Friar&#39;s Roast of Jane Goodall ; BeyTfqDghrM ; 2007-04-18T02:18:34Z
# 2007 W. P. Carey Roast and Toast- Opening Sketch ; m4YikJYdkGY ; 2007-04-28T21:40:48Z
# ROAST ME?!! Yeah right Mutha Fu &#39;s! ; 3ivLgS337uQ ; 2007-07-17T21:34:56Z
# Jerry Shereshewsky ; 3e8UypFobTQ ; 2007-08-01T14:27:48Z
# friars club roast Yahoo! Shereshewsky ; 9odrJQTjROA ; 2007-09-01T14:07:15Z
# david &amp; lara simon roast video ; nHen5KDAWes ; 2007-09-02T23:53:47Z
# What is Grandparents.com? ; nSFmq7R5bac ; 2007-09-07T15:49:02Z
# Jenkem The Movie Trailer ; czkwIokPiXw ; 2007-12-13T06:08:30Z
